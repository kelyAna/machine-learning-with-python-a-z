# %% [markdown]
# Importações Iniciais

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering

# %% [markdown]
# Leitura do DataSet

# %%
df = pd.read_csv('credit_card_clients.csv', header = 1)
df
# Out:
#           ID  LIMIT_BAL  SEX  ...  PAY_AMT5  PAY_AMT6  default payment next month
# 0          1      20000    2  ...         0         0                           1
# 1          2     120000    2  ...         0      2000                           1
# 2          3      90000    2  ...      1000      5000                           0
# 3          4      50000    2  ...      1069      1000                           0
# 4          5      50000    1  ...       689       679                           0
# ...      ...        ...  ...  ...       ...       ...                         ...
# 29995  29996     220000    1  ...      5000      1000                           0
# 29996  29997     150000    1  ...         0         0                           0
# 29997  29998      30000    1  ...      2000      3100                           1
# 29998  29999      80000    1  ...     52964      1804                           1
# 29999  30000      50000    1  ...      1000      1000                           1
#
# [30000 rows x 25 columns]

# %% [markdown]
# Adicionando uma coluna a mais, com o total de salários

# %%
df['BILL_TOTAL'] = df['BILL_AMT1'] + df['BILL_AMT2'] + df['BILL_AMT3'] + df['BILL_AMT4'] + df['BILL_AMT5'] + df['BILL_AMT6']
df
# Out:
#           ID  LIMIT_BAL  SEX  ...  PAY_AMT6  default payment next month  BILL_TOTAL
# 0          1      20000    2  ...         0                           1        7704
# 1          2     120000    2  ...      2000                           1       17077
# 2          3      90000    2  ...      5000                           0      101653
# 3          4      50000    2  ...      1000                           0      231334
# 4          5      50000    1  ...       679                           0      109339
# ...      ...        ...  ...  ...       ...                         ...         ...
# 29995  29996     220000    1  ...      1000                           0      725349
# 29996  29997     150000    1  ...         0                           0       21182
# 29997  29998      30000    1  ...      3100                           1       70496
# 29998  29999      80000    1  ...      1804                           1      266611
# 29999  30000      50000    1  ...      1000                           1      230874
#
# [30000 rows x 26 columns]

# %% [markdown]
# Transformando os valores do DataSet em uma matriz numpy

# %%
X = df.iloc[:,[1,25]].values
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# Criando o dendrograma

# %%
dendrograma = dendrogram(linkage(X, method='ward'))

# %%
hc = AgglomerativeClustering(n_clusters=3, affinity='euclidean',linkage='ward')

# %%
previsoes = hc.fit_predict(X)

# %%
plt.scatter(X[previsoes == 0, 0], X[previsoes == 0, 1], s = 100, c = 'red', label = 'Clusters 1')
plt.scatter(X[previsoes == 1, 0], X[previsoes == 1, 1], s = 100, c = 'blue', label = 'Clusters 2')
plt.scatter(X[previsoes == 2, 0], X[previsoes == 2, 1], s = 100, c = 'green', label = 'Clusters 3')
plt.xlabel('Limite')
plt.ylabel('Gastos')
plt.legend()
